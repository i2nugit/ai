# %%
from IPython.display import display, HTML
display(HTML("""
<style>
div.container{width:85% !important;}
div.cell.code_cell.rendered{width:100%;}
div.input_prompt{padding:0px;}
div.CodeMirror {font-family:Consolas; font-size:12pt;}
div.output {font-size:12pt; font-weight:bold;}
div.input {font-family:Consolas; font-size:12pt;}
div.prompt {min-width:70px;}
div#toc-wrapper{padding-top:120px;}
div.text_cell_render ul li{font-size:12pt;padding:5px;}
table.dataframe{font-size:12px;}
</style>
"""))
# Out:
# <style>
# div.container{width:85% !important;}
# div.cell.code_cell.rendered{width:100%;}
# div.input_prompt{padding:0px;}
# div.CodeMirror {font-family:Consolas; font-size:12pt;}
# div.output {font-size:12pt; font-weight:bold;}
# div.input {font-family:Consolas; font-size:12pt;}
# div.prompt {min-width:70px;}
# div#toc-wrapper{padding-top:120px;}
# div.text_cell_render ul li{font-size:12pt;padding:5px;}
# table.dataframe{font-size:12px;}
# </style>

# %% [markdown]
# <font size="5" color="black">ch01. 파이썬 개요 및 환경 설정</font>
# # 1. 마크다운이란?
# - 코드와 함께 문서화할 수 있음
# - 다양한 문서화 문법 존재 ex) README.md
#
# # 2. 주피터 노트북 실행법
# - shift + enter : 포커스된 셀이 실행, 커서가 다음 셀로 이동
# - alt + enter : 포커스된 셀이 실행, 다음 셀 생성 후 다음 셀로 이동
# - ctrl + enter : 포커스된 셀이 실행, 포커스 이동 x
# - enter : 재편집

# %%
# 주석 설정 (실행 안됨)
# 셀 하나하나에 파이썬 실행 소스 입력

# %%
# print() 함수를 이용해 출력
print('Hello, World')
print("Hello\n\n홍길동")
# Out:
# Hello, World
# Hello
#
# 홍길동

# %%
age = 25
duration = "2"
print(age + int(duration))
print(str(age) + duration)
# Out:
# 27
# 252

# %%
# view > toggle line ㅜumber 선택

# %% [markdown]
# # 3. esc + (hot key setting)
# - dd : 셀 삭제
# - b : 포커스된 셀 아래에 셀 추가
# - a : 포커스된 셀 위에 셀 추가
# - m : 마크다운 셀(문서 셀)로 변경
# - y : 코드 셀(소스 셀)로 변경
# - o : 실행 결과 접기/펴기(토글)

# %%
# 주피터 노트북에서 cmd 명령어 (!)
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 0C81-36F7
#
#  C:\ai\source\01_python 디렉터리
#
# 2026-06-23  오전 11:38    <DIR>          .
# 2026-06-22  오후 02:29    <DIR>          ..
# 2026-06-23  오전 10:55    <DIR>          .ipynb_checkpoints
# 2026-06-23  오전 11:38             5,387 ch01_파이썬 개요 및 환경설정.ipynb
#                1개 파일               5,387 바이트
#                3개 디렉터리  155,843,223,552 바이트 남음

# %%
# 매직 명령어 (주피터 노트북 자체 명령어 (%); 파이썬 x)
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 0C81-36F7
#
#  C:\ai\source\01_python 디렉터리
#
# 2026-06-23  오전 11:38    <DIR>          .
# 2026-06-22  오후 02:29    <DIR>          ..
# 2026-06-23  오전 10:55    <DIR>          .ipynb_checkpoints
# 2026-06-23  오전 11:38             5,387 ch01_파이썬 개요 및 환경설정.ipynb
#                1개 파일               5,387 바이트
#                3개 디렉터리  155,841,990,656 바이트 남음
